# %%
import pandas as pd

# %%
file = ("Resources/Most-Recent-Cohorts-Treasury-Elements.csv")

# %%
data = pd.read_csv(file)
data.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM  COUNT_ED  \
# 0  100654   100200    1002             Alabama A & M University       NaN
# 1  100663   105200    1052  University of Alabama at Birmingham       NaN
# 2  100690  2503400   25034                   Amridge University       NaN
# 3  100706   105500    1055  University of Alabama in Huntsville       NaN
# 4  100724   100500    1005             Alabama State University       NaN
#
#             AGEGE24         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# 0  0.07999999821186  46.8400001525878  47.9799995422363  1.48000001907348
# 1  0.25999999046325  69.0199966430664  27.7600002288818  1.10000002384185
# 2  0.82999998331069  70.8799972534179  22.5300006866455  1.28999996185302
# 3  0.28999999165534  76.3799972534179  18.9799995422363  1.41999995708465
# 4  0.10999999940395  42.6899986267089  52.3199996948242  1.40999996662139
#
#        PCT_HISPANIC    ...    SD_EARN_WNE_P8 GT_25K_P8 COUNT_NWNE_P9  \
# ...

# %%
earnings_data = data.rename(columns={"MEDIAN_HH_INC":"Median_hh_income",
                                     "POVERTY_RATE": "Poverty_rate",
                                     "UNEMP_RATE": "Unemployment_rate",
                                     "MD_EARN_WNE_P6": "Median_earn_6yr_postgrad",
                                     "MN_EARN_WNE_P6": "Mean_earn_6yr_postgrad",
                                     "MD_EARN_WNE_P7": "Median_earn_7yr_postgrad",
                                     "MN_EARN_WNE_P7": "Mean_earn_7yr_postgrad",
                                     "MD_EARN_WNE_P8": "Median_earn_8yr_postgrad",
                                     "MN_EARN_WNE_P8" : "Mean_earn_8yr_postgrad",
                                     "MD_EARN_WNE_P10": "Median_earn_10yr_postgrad",
                                     "MN_EARN_WNE_P10": "Mean_earn_10yr_postgrad",
                                     "MN_EARN_WNE_MALE0_P10": "Mean_earn_10yr_postgrad_female",
                                     "MN_EARN_WNE_MALE1_P10": "Mean_earn_10yr_postgrad_male",
                                     "COUNT_WNE_INC1_P10": "Num_stud_10yr_postgrad_earn_less_30k",
                                     "COUNT_WNE_INC2_P10": "Num_stud_10yr_postgrad_earn_30_75k",
                                     "COUNT_WNE_INC3_P10": "Num_stud_10yr_postgrad_earn_75k_more",
                                     "MN_EARN_WNE_INC1_P10": "Mean_stud_10yr_postgrad_earn_less_30k",
                                     "MN_EARN_WNE_INC2_P10": "Mean_stud_10yr_postgrad_earn_30_75k",
                                     "MN_EARN_WNE_INC3_P10": "Num_stud_10yr_postgrad_earn_75k_more",
                                     "COUNT_WNE_INC1_P6": "Num_stud_6yr_postgrad_earn_less_30k",
                                     "COUNT_WNE_INC2_P6": "Num_stud_6yr_postgrad_earn_30_75k",
                                     "COUNT_WNE_INC3_P6": "Num_stud_6yr_postgrad_earn_75k_more",
                                     "MN_EARN_WNE_INC1_P6": "Mean_stud_6yr_postgrad_earn_less_30k",
                                     "MN_EARN_WNE_INC2_P6": "Mean_stud_6yr_postgrad_earn_30_75k",
                                     "MN_EARN_WNE_INC3_P6": "Num_stud_6yr_postgrad_earn_75k_more"
                                     })

# %%
earnings_df = earnings_data[["UNITID", "INSTNM", "Median_hh_income", "Poverty_rate", "Unemployment_rate", "Median_earn_6yr_postgrad",
                             "Mean_earn_6yr_postgrad", "Mean_earn_7yr_postgrad", "Median_earn_8yr_postgrad", "Mean_earn_8yr_postgrad", "Median_earn_10yr_postgrad",
                            "Mean_earn_10yr_postgrad", "Mean_earn_10yr_postgrad_female", "Mean_earn_10yr_postgrad_male", "Num_stud_10yr_postgrad_earn_less_30k", 
                             "Num_stud_10yr_postgrad_earn_less_30k", "Num_stud_10yr_postgrad_earn_30_75k", "Num_stud_10yr_postgrad_earn_75k_more",
                            "Mean_stud_10yr_postgrad_earn_less_30k", "Mean_stud_10yr_postgrad_earn_30_75k", "Num_stud_10yr_postgrad_earn_75k_more",
                            "Num_stud_6yr_postgrad_earn_less_30k", "Num_stud_6yr_postgrad_earn_30_75k", "Num_stud_6yr_postgrad_earn_75k_more",
                            "Mean_stud_6yr_postgrad_earn_less_30k", "Mean_stud_6yr_postgrad_earn_30_75k", "Num_stud_6yr_postgrad_earn_75k_more"
                            ]]
earnings_df.head()
# Out:
#    UNITID                               INSTNM Median_hh_income  \
# 0  100654             Alabama A & M University         49720.22
# 1  100663  University of Alabama at Birmingham         55735.22
# 2  100690                   Amridge University          53683.7
# 3  100706  University of Alabama in Huntsville         58688.62
# 4  100724             Alabama State University          46065.2
#
#        Poverty_rate Unemployment_rate Median_earn_6yr_postgrad  \
# 0  14.8800001144409  4.84000015258789                    25200
# 1  10.9099998474121  3.45000004768371                    35100
# 2  10.6499996185302  3.59999990463256                    30700
# 3  9.36999988555908  3.64000010490417                    36200
# 4  16.9599990844726  4.80999994277954                    22600
#
#   Mean_earn_6yr_postgrad Mean_earn_7yr_postgrad Median_earn_8yr_postgrad  \
# 0                  28400                  29600                    27100
# ...

# %%
earnings_df.to_csv("Output/post_school_earnings.csv")

# %%
earnings_7yr = earnings_data[["UNITID", "INSTNM", "Mean_earn_7yr_postgrad"]]
earnings_7yr.head()
# Out:
#    UNITID                               INSTNM Mean_earn_7yr_postgrad
# 0  100654             Alabama A & M University                  29600
# 1  100663  University of Alabama at Birmingham                  40000
# 2  100690                   Amridge University                  38700
# 3  100706  University of Alabama in Huntsville                  43400
# 4  100724             Alabama State University                  25200

# %%
earnings_7yr.to_csv("Output/earnings_7yr.csv")

# %%
earnings_general = earnings_data[["UNITID", "INSTNM", "Median_hh_income", "Poverty_rate", "Unemployment_rate"]]
earnings_general.head()
# Out:
#    UNITID                               INSTNM Median_hh_income  \
# 0  100654             Alabama A & M University         49720.22
# 1  100663  University of Alabama at Birmingham         55735.22
# 2  100690                   Amridge University          53683.7
# 3  100706  University of Alabama in Huntsville         58688.62
# 4  100724             Alabama State University          46065.2
#
#        Poverty_rate Unemployment_rate
# 0  14.8800001144409  4.84000015258789
# 1  10.9099998474121  3.45000004768371
# 2  10.6499996185302  3.59999990463256
# 3  9.36999988555908  3.64000010490417
# 4  16.9599990844726  4.80999994277954

# %%
earnings_general.to_csv("Output/earnings_general.csv")

# %%
earnings_6yr = earnings_data[["UNITID", "INSTNM",  "Median_earn_6yr_postgrad","Mean_earn_6yr_postgrad",                     
                            "Num_stud_6yr_postgrad_earn_less_30k", "Num_stud_6yr_postgrad_earn_30_75k", "Num_stud_6yr_postgrad_earn_75k_more",
                            "Mean_stud_6yr_postgrad_earn_less_30k", "Mean_stud_6yr_postgrad_earn_30_75k", "Num_stud_6yr_postgrad_earn_75k_more"]]
earnings_6yr.head()
# Out:
#    UNITID                               INSTNM Median_earn_6yr_postgrad  \
# 0  100654             Alabama A & M University                    25200
# 1  100663  University of Alabama at Birmingham                    35100
# 2  100690                   Amridge University                    30700
# 3  100706  University of Alabama in Huntsville                    36200
# 4  100724             Alabama State University                    22600
#
#   Mean_earn_6yr_postgrad Num_stud_6yr_postgrad_earn_less_30k  \
# 0                  28400                                 653
# 1                  39400                                1052
# 2                  35400                                  75
# 3                  40300                                 540
# 4                  24400                                1065
#
#   Num_stud_6yr_postgrad_earn_30_75k Num_stud_6yr_postgrad_earn_75k_more  \
# 0                               431                                 220
# ...

# %%
earnings_6yr.to_csv("Output/earnings_6yr.csv")

# %%
earnings_8yr = earnings_data[["UNITID", "INSTNM", "Median_earn_8yr_postgrad", "Mean_earn_8yr_postgrad"]]
earnings_8yr.head()
# Out:
#    UNITID                               INSTNM Median_earn_8yr_postgrad  \
# 0  100654             Alabama A & M University                    27100
# 1  100663  University of Alabama at Birmingham                    38300
# 2  100690                   Amridge University                    38300
# 3  100706  University of Alabama in Huntsville                    41800
# 4  100724             Alabama State University                    25200
#
#   Mean_earn_8yr_postgrad
# 0                  30600
# 1                  44100
# 2                  40800
# 3                  45900
# 4                  27500

# %%
earnings_8yr.to_csv("Output/earnings_8yr.csv")

# %%
earnings_10yr = earnings_data[["UNITID", "INSTNM", "Median_earn_10yr_postgrad","Mean_earn_10yr_postgrad", "Mean_earn_10yr_postgrad_female", "Mean_earn_10yr_postgrad_male", 
                               "Num_stud_10yr_postgrad_earn_less_30k", "Num_stud_10yr_postgrad_earn_less_30k", "Num_stud_10yr_postgrad_earn_30_75k", "Num_stud_10yr_postgrad_earn_75k_more",
                            "Mean_stud_10yr_postgrad_earn_less_30k", "Mean_stud_10yr_postgrad_earn_30_75k", "Num_stud_10yr_postgrad_earn_75k_more"]]
earnings_10yr.head()
# Out:
#    UNITID                               INSTNM Median_earn_10yr_postgrad  \
# 0  100654             Alabama A & M University                     31000
# 1  100663  University of Alabama at Birmingham                     41200
# 2  100690                   Amridge University                     39600
# 3  100706  University of Alabama in Huntsville                     46700
# 4  100724             Alabama State University                     27700
#
#   Mean_earn_10yr_postgrad Mean_earn_10yr_postgrad_female  \
# 0                   35500                          32600
# 1                   48400                          43200
# 2                   47600                          38700
# 3                   52000                          46000
# 4                   30600                          28300
#
#   Mean_earn_10yr_postgrad_male Num_stud_10yr_postgrad_earn_less_30k  \
# 0                        38500                                  878
# ...

# %%
earnings_10yr.to_csv("Output/earnings_10yr.csv")

# %%
earnings_gender = earnings_data[["UNITID", "INSTNM", "Mean_earn_10yr_postgrad_female", "Mean_earn_10yr_postgrad_male"]]
earnings_gender.head()
# Out:
#    UNITID                               INSTNM Mean_earn_10yr_postgrad_female  \
# 0  100654             Alabama A & M University                          32600
# 1  100663  University of Alabama at Birmingham                          43200
# 2  100690                   Amridge University                          38700
# 3  100706  University of Alabama in Huntsville                          46000
# 4  100724             Alabama State University                          28300
#
#   Mean_earn_10yr_postgrad_male
# 0                        38500
# 1                        57400
# 2                        56000
# 3                        58700
# 4                        33000

# %%
earnings_gender.to_csv("Output/earnings_gender.csv")
