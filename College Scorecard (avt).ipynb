# %%
#Dependencies 
import pandas as pd

# %%
#Load the CSV file
load_file = "Resources/v2_MERGED2016_17_PP.csv"

# %%
#Create DataFrame from CSV file
college_df = pd.read_csv(load_file)

# %%
#List all the columns 
college_df.columns
# Out:
# Index(['UNITID', 'Institution_Name', 'Degree_Granted',
#        'Public_Privatenp_Privatefp', 'Region', 'Carnegie_Classification',
#        'Men_Only', 'Women_Only', 'Sat_Mp_Critical_Reading', 'Sat_Mp_Math',
#        'Sat_Mp_Writing', 'Communication_Journalism',
#        'Computer_And_Information_Sciences', 'Engineering', 'Liberal_Arts',
#        'Math_And_Statistics', 'Social_Sciences', 'Business',
#        'Enrollment_Of_Undergrads_And_Certificate_Students',
#        'Average_Cost_Of_Attendance_By_Academic_Year', 'Instate_Tuition_&_Fees',
#        'Out_Of_State_Tuition_&_Fees', '%_Of_All_Undergrads_Receving_Fafsa',
#        'Female_7_Year_Repayment_Rate', 'Male_7_Year_Repayment_Rate',
#        '1St_Gen_7_Year_Repayment_Rate', 'Non_1St_Gen_7_Year_Repayment_Rate',
#        'Percentage_Of_1St_Gen_Students', 'Median_Debt_For_Female_Students',
#        'Median_Debt_For_Male_Students', 'Median_Debt_For_1St_Gen_Students',
#        'Median_Debt_For_Non_1St_Gen_Students'],
# ...

# %%
#Print the original DataFrame
college_df.head()
# Out:
#    UNITID                     Institution_Name  Degree_Granted  \
# 0  100654             Alabama A & M University               3
# 1  100663  University of Alabama at Birmingham               3
# 2  100690                   Amridge University               3
# 3  100706  University of Alabama in Huntsville               3
# 4  100724             Alabama State University               3
#
#    Public_Privatenp_Privatefp  Region  Carnegie_Classification  Men_Only  \
# 0                           1       5                     18.0       0.0
# 1                           1       5                     15.0       0.0
# 2                           2       5                     20.0       0.0
# 3                           1       5                     16.0       0.0
# 4                           1       5                     19.0       0.0
#
#    Women_Only  Sat_Mp_Critical_Reading  Sat_Mp_Math  \
# 0         0.0                    425.0        420.0
# ...

# %%
#Create new DataFrame with debt and repayment information.
debt_repymt_df = college_df[['UNITID', 'Institution_Name', 'Degree_Granted', 'Female_7_Year_Repayment_Rate', 'Male_7_Year_Repayment_Rate', '1St_Gen_7_Year_Repayment_Rate', 'Non_1St_Gen_7_Year_Repayment_Rate', 
                             'Median_Debt_For_Female_Students', 'Median_Debt_For_Male_Students', 'Median_Debt_For_1St_Gen_Students', 'Median_Debt_For_Non_1St_Gen_Students']]
debt_repymt_df.head()
# Out:
#    UNITID                     Institution_Name  Degree_Granted  \
# 0  100654             Alabama A & M University               3
# 1  100663  University of Alabama at Birmingham               3
# 2  100690                   Amridge University               3
# 3  100706  University of Alabama in Huntsville               3
# 4  100724             Alabama State University               3
#
#   Female_7_Year_Repayment_Rate Male_7_Year_Repayment_Rate  \
# 0                  0.406060606                0.360894942
# 1                  0.632850242                0.647241647
# 2                  0.383116883                0.495934959
# 3                  0.623612513                0.675707547
# 4                  0.341089671                0.298909091
#
#   1St_Gen_7_Year_Repayment_Rate Non_1St_Gen_7_Year_Repayment_Rate  \
# 0                   0.397887324                       0.376408715
# 1                    0.63523744                       0.639344262
# ...

# %%
#Revise wording of values
debt_repymt_df.loc[debt_repymt_df.Degree_Granted == 0, 'Predom_DegreeGranting'] = 'Not Classified'  
debt_repymt_df.loc[debt_repymt_df.Degree_Granted == 1, 'Predom_DegreeGranting'] = 'Predominantly Cert-Degree Granting'  
debt_repymt_df.loc[debt_repymt_df.Degree_Granted == 2, 'Predom_DegreeGranting'] = 'Predominantly Assoc-Degree Granting' 
debt_repymt_df.loc[debt_repymt_df.Degree_Granted == 3, 'Predom_DegreeGranting'] = 'Predominantly BS-Degree Granting' 
debt_repymt_df.loc[debt_repymt_df.Degree_Granted == 4, 'Predom_DegreeGranting'] = 'Entirely Grad-Degree Granting' 
debt_repymt_df.head()
# Out:
# C:\Users\avargastonsi\AppData\Local\Continuum\anaconda3\envs\UNCData\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\avargastonsi\AppData\Local\Continuum\anaconda3\envs\UNCData\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#    UNITID                     Institution_Name  Degree_Granted  \
# 0  100654             Alabama A & M University               3
# ...

# %%
#Remove Degree_Granted column
del debt_repymt_df['Degree_Granted']
debt_repymt_df.head()
# Out:
#    UNITID                     Institution_Name Female_7_Year_Repayment_Rate  \
# 0  100654             Alabama A & M University                  0.406060606
# 1  100663  University of Alabama at Birmingham                  0.632850242
# 2  100690                   Amridge University                  0.383116883
# 3  100706  University of Alabama in Huntsville                  0.623612513
# 4  100724             Alabama State University                  0.341089671
#
#   Male_7_Year_Repayment_Rate 1St_Gen_7_Year_Repayment_Rate  \
# 0                0.360894942                   0.397887324
# 1                0.647241647                    0.63523744
# 2                0.495934959                   0.446666667
# 3                0.675707547                   0.650246305
# 4                0.298909091                   0.326937269
#
#   Non_1St_Gen_7_Year_Repayment_Rate Median_Debt_For_Female_Students  \
# 0                       0.376408715                           14250
# ...

# %%
#Reorganize columns
debt_repymt2_df = debt_repymt_df[['UNITID', 'Institution_Name', 'Predom_DegreeGranting', 'Median_Debt_For_Female_Students', 'Median_Debt_For_Male_Students', 'Median_Debt_For_1St_Gen_Students', 
                                 'Median_Debt_For_Non_1St_Gen_Students', 'Female_7_Year_Repayment_Rate', 'Male_7_Year_Repayment_Rate', '1St_Gen_7_Year_Repayment_Rate', 'Non_1St_Gen_7_Year_Repayment_Rate']]
debt_repymt2_df.head()
# Out:
#    UNITID                     Institution_Name  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#               Predom_DegreeGranting Median_Debt_For_Female_Students  \
# 0  Predominantly BS-Degree Granting                           14250
# 1  Predominantly BS-Degree Granting                           15000
# 2  Predominantly BS-Degree Granting                           12500
# 3  Predominantly BS-Degree Granting                           14250
# 4  Predominantly BS-Degree Granting                           17500
#
#   Median_Debt_For_Male_Students Median_Debt_For_1St_Gen_Students  \
# 0                         12072                            12250
# 1                         14250                            14250
# 2                          9500                             9500
# ...

# %%
#Rename columns
renamed_debtRepymt_df = debt_repymt2_df.rename(columns={'Median_Debt_For_Female_Students': 'Med Student Debt (Female)', 'Median_Debt_For_Male_Students': 'Med Student Debt (Male)',
                                                       'Median_Debt_For_1St_Gen_Students': 'Med Student Debt (First Gen)', 'Median_Debt_For_Non_1St_Gen_Students': 'Med Student Debt (Non-First Gen)', 'Female_7_Year_Repayment_Rate': '7yr Repymt Rate (Female)', 
                                                        'Male_7_Year_Repayment_Rate': '7yr Repymt Rate (Male)', '1St_Gen_7_Year_Repayment_Rate': '7yr Repymt Rate (First Gen)', 'Non_1St_Gen_7_Year_Repayment_Rate': '7yr Repymt Rate (Non-Firs Gen)'})
renamed_debtRepymt_df.head()
# Out:
#    UNITID                     Institution_Name  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#               Predom_DegreeGranting Med Student Debt (Female)  \
# 0  Predominantly BS-Degree Granting                     14250
# 1  Predominantly BS-Degree Granting                     15000
# 2  Predominantly BS-Degree Granting                     12500
# 3  Predominantly BS-Degree Granting                     14250
# 4  Predominantly BS-Degree Granting                     17500
#
#   Med Student Debt (Male) Med Student Debt (First Gen)  \
# 0                   12072                        12250
# 1                   14250                        14250
# 2                    9500                         9500
# 3                 12733.5                      13620.5
# ...

# %%
#Create new DataFrame with degree and major information.
degMaj_df = college_df[['UNITID', 'Institution_Name', 'Degree_Granted', 'Communication_Journalism', 'Computer_And_Information_Sciences', 'Engineering', 'Liberal_Arts', 'Math_And_Statistics',
                            'Social_Sciences', 'Business']]
degMaj_df.head()
# Out:
#    UNITID                     Institution_Name  Degree_Granted  \
# 0  100654             Alabama A & M University               3
# 1  100663  University of Alabama at Birmingham               3
# 2  100690                   Amridge University               3
# 3  100706  University of Alabama in Huntsville               3
# 4  100724             Alabama State University               3
#
#    Communication_Journalism  Computer_And_Information_Sciences  Engineering  \
# 0                    0.0000                             0.0401       0.0896
# 1                    0.0360                             0.0131       0.0599
# 2                    0.0000                             0.0000       0.0000
# 3                    0.0301                             0.0499       0.2702
# 4                    0.1023                             0.0503       0.0000
#
#    Liberal_Arts  Math_And_Statistics  Social_Sciences  Business
# 0        0.0660               0.0024           0.0448    0.1863
# ...

# %%
#Revise wording of values
degMaj_df.loc[degMaj_df.Degree_Granted == 0, 'Predom_DegreeGranting'] = 'Not Classified'  
degMaj_df.loc[degMaj_df.Degree_Granted == 1, 'Predom_DegreeGranting'] = 'Predominantly Cert-Degree Granting'  
degMaj_df.loc[degMaj_df.Degree_Granted == 2, 'Predom_DegreeGranting'] = 'Predominantly Assoc-Degree Granting' 
degMaj_df.loc[degMaj_df.Degree_Granted == 3, 'Predom_DegreeGranting'] = 'Predominantly BS-Degree Granting' 
degMaj_df.loc[degMaj_df.Degree_Granted == 4, 'Predom_DegreeGranting'] = 'Entirely Grad-Degree Granting' 
degMaj_df.head()
# Out:
#    UNITID                     Institution_Name  Degree_Granted  \
# 0  100654             Alabama A & M University               3
# 1  100663  University of Alabama at Birmingham               3
# 2  100690                   Amridge University               3
# 3  100706  University of Alabama in Huntsville               3
# 4  100724             Alabama State University               3
#
#    Communication_Journalism  Computer_And_Information_Sciences  Engineering  \
# 0                    0.0000                             0.0401       0.0896
# 1                    0.0360                             0.0131       0.0599
# 2                    0.0000                             0.0000       0.0000
# 3                    0.0301                             0.0499       0.2702
# 4                    0.1023                             0.0503       0.0000
#
#    Liberal_Arts  Math_And_Statistics  Social_Sciences  Business  \
# ...

# %%
#Remove Degree_Granted column
del degMaj_df['Degree_Granted']
degMaj_df.head()
# Out:
#    UNITID                     Institution_Name  Communication_Journalism  \
# 0  100654             Alabama A & M University                    0.0000
# 1  100663  University of Alabama at Birmingham                    0.0360
# 2  100690                   Amridge University                    0.0000
# 3  100706  University of Alabama in Huntsville                    0.0301
# 4  100724             Alabama State University                    0.1023
#
#    Computer_And_Information_Sciences  Engineering  Liberal_Arts  \
# 0                             0.0401       0.0896        0.0660
# 1                             0.0131       0.0599        0.0135
# 2                             0.0000       0.0000        0.0889
# 3                             0.0499       0.2702        0.0000
# 4                             0.0503       0.0000        0.0000
#
#    Math_And_Statistics  Social_Sciences  Business  \
# 0               0.0024           0.0448    0.1863
# ...

# %%
#Reorganize columns
degMaj2_df = degMaj_df[['UNITID', 'Institution_Name', 'Predom_DegreeGranting', 'Communication_Journalism', 'Computer_And_Information_Sciences', 'Engineering', 'Liberal_Arts', 
                                 'Math_And_Statistics', 'Social_Sciences', 'Business']]
degMaj2_df.head()
# Out:
#    UNITID                     Institution_Name  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#               Predom_DegreeGranting  Communication_Journalism  \
# 0  Predominantly BS-Degree Granting                    0.0000
# 1  Predominantly BS-Degree Granting                    0.0360
# 2  Predominantly BS-Degree Granting                    0.0000
# 3  Predominantly BS-Degree Granting                    0.0301
# 4  Predominantly BS-Degree Granting                    0.1023
#
#    Computer_And_Information_Sciences  Engineering  Liberal_Arts  \
# 0                             0.0401       0.0896        0.0660
# 1                             0.0131       0.0599        0.0135
# 2                             0.0000       0.0000        0.0889
# ...

# %%
#Rename columns
renamed_degMajor_df = degMaj2_df.rename(columns={'Communication_Journalism':'% Degree Granted (Comm & Journalism)', 'Computer_And_Information_Sciences':'% Degree Granted (Comp & Info Sci)',
                                                       'Engineering': '% Degree Granted (Engineering)', 'Liberal_Arts': '% Degree Granted (Lib Arts)', 'Math_And_Statistics': '% Degree Granted (Math & Stats)', 
                                                        'Social_Sciences': '% Degree Granted (Soc Sci)', 'Business': '% Degree Granted (Bus)'})
renamed_degMajor_df.head()
# Out:
#    UNITID                     Institution_Name  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#               Predom_DegreeGranting  % Degree Granted (Comm & Journalism)  \
# 0  Predominantly BS-Degree Granting                                0.0000
# 1  Predominantly BS-Degree Granting                                0.0360
# 2  Predominantly BS-Degree Granting                                0.0000
# 3  Predominantly BS-Degree Granting                                0.0301
# 4  Predominantly BS-Degree Granting                                0.1023
#
#    % Degree Granted (Comp & Info Sci)  % Degree Granted (Engineering)  \
# 0                              0.0401                          0.0896
# 1                              0.0131                          0.0599
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
renamed_debtRepymt_df.to_csv("Output/debtRepymt.csv", index=False, header=True)

# %%
# Export file as a CSV, without the Pandas index, but with the header
renamed_degMajor_df.to_csv("Output/degreeMajor.csv", index=False, header=True)
